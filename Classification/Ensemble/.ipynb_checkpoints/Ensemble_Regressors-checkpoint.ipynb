# %% [markdown]
# # RandomForestRegressor, AdaBoostRegressor, radientBoostingRegressor

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from ipywidgets import interact
from sklearn.metrics import classification_report

# %% [markdown]
# ## Random Forest Regression
#
# In the previous section we considered random forests within the context of classification.
# Random forests can also be made to work in the case of regression (that is, continuous rather than categorical variables). The estimator to use for this is the ``RandomForestRegressor``, and the syntax is very similar to what we saw earlier.
#
# Consider the following data, drawn from the combination of a fast and slow oscillation:

# %%
rng = np.random.RandomState(42)
x = 2 * rng.rand(200)

def model(x, sigma=0.3):
    fast_oscillation = np.sin(5 * x)
    slow_oscillation = np.sin(0.5 * x)
    noise = sigma * rng.randn(len(x))

    return slow_oscillation + fast_oscillation + noise

y = model(x)
plt.errorbar(x, y, fmt='o');

# %% [markdown]
# Using the random forest regressor, we can find the best fit curve as follows:

# %%
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
tree = DecisionTreeRegressor()
tree.fit(x[:, None], y)

xfit = np.linspace(0, 2, 1000)
yfit = tree.predict(xfit[:, None])
ytrue = model(xfit, sigma=0)

plt.errorbar(x, y, fmt='o', alpha=0.5)
plt.plot(xfit, yfit, '-r');
plt.plot(xfit, ytrue, '-g', alpha=0.9);

# %% [markdown]
# ### RandomForestRegressor

# %%
forest = RandomForestRegressor(200)
forest.fit(x[:, None], y)

xfit = np.linspace(0, 2, 1000)
yfit = forest.predict(xfit[:, None])
ytrue = model(xfit, sigma=0)

plt.errorbar(x, y, fmt='o', alpha=0.5)
plt.plot(xfit, yfit, '-r');
plt.plot(xfit, ytrue, '-g', alpha=0.8);

# %% [markdown]
# ### AdaBoostRegressor

# %%
forest = AdaBoostRegressor(n_estimators=200)
forest.fit(x[:, None], y)

xfit = np.linspace(0, 2, 1000)
yfit = forest.predict(xfit[:, None])
ytrue = model(xfit, sigma=0)

plt.errorbar(x, y, fmt='o', alpha=0.5)
plt.plot(xfit, yfit, '-r');
plt.plot(xfit, ytrue, '-g', alpha=0.8);

# %% [markdown]
# ### GradientBoostingRegressor

# %%
forest = GradientBoostingRegressor(n_estimators=100)
forest.fit(x[:, None], y)

xfit = np.linspace(0, 2, 1000)
yfit = forest.predict(xfit[:, None])
ytrue = model(xfit, sigma=0)

plt.errorbar(x, y, fmt='o', alpha=0.5)
plt.plot(xfit, yfit, '-r');
plt.plot(xfit, ytrue, '-g', alpha=0.8);

# %% [markdown]
# Here the true model is shown in the smooth gray curve, while the random forest model is shown by the jagged red curve.
# As you can see, the non-parametric random forest model is flexible enough to fit the multi-period data, without us needing to specifying a multi-period model!
